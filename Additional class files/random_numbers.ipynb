# %%
#import random number module
import random

# %%
random.randint(-90, 90)
# Out:
# 20

# %%
random.random()
# Out:
# 0.8868302811461436

# %%
#combining random and randint functions to get a latitutde number
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 33.663074004806425

# %%
#using the randrange function
random.randrange(-90, 90, step=1)
# Out:
# 60

# %%
random.randrange(-90, 90, step=3)
# Out:
# 21

# %%
#using uniform() function
random.uniform(-90, 90)
# Out:
# 87.43902166039143

# %%
#randint(-90, 89)--returns integer between interval specified; will not generate a floating point decimal
#random()--returns a flaoting-point decimal between 0 and 1; will not generate a whole integer
#randrange(-90, 90, step=1)--returns a whole integer bewtween the specified interval where the step is the difference between each number;
#                          will not generate a floating point decimal
#uniform(-90, 90)--returns a floating point decimal number between the given interval; will not generate a whole integer

# %%
#combine NumPy and random modules
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -78.33565637759166

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 56.66474198, -60.74640048,  21.722931  , -63.32175127,
#        -35.96115084,  10.51203524, -17.97414963, -12.97924215,
#        -73.13166646,  67.30310266,  -6.72497356,  65.41082785,
#        -22.34165955, -39.75490106, -37.3938727 , -79.46555336,
#        -29.4598189 , -22.80245395,  86.07841943, -75.74956654,
#         66.35281716, -61.97722828,  -3.63464502, -60.60564124,
#         22.49694368,  72.59300234,  71.7373866 ,  72.13640102,
#         11.22149821, -34.66841845, -81.67215846,  57.55938057,
#        -59.77238052, -40.24358483,  -5.81753629,  -8.14545437,
#        -33.47664144, -69.98041479, -66.30232287, -51.08084307,
#         29.24210891, -77.87921102, -85.1185669 ,  -3.26157373,
#        -75.53999724,  14.8857678 , -89.56066453, -69.83967228,
#         29.8538468 ,  13.20913658])

# %%
#testing if it is faster to combine numpy and uniform or to use a For loop
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 11.7 µs ± 20.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
       #return latitudes
#call the function with 1500
# %timeit latitudes(1500)
# Out:
# 996 ns ± 3.58 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
#writing a for loop that will generate 1500 latitudes

latitudes_array = []
x = 1
while x < 1501:
    random_lat = random.randint(-90, 90) + random.random()
    latitudes_array.append(random_lat)
    x += 1

# %%
latitudes_array
# Out:
# [47.439693989437494,
#  -58.19720817612231,
#  -50.15542010504103,
#  10.953160659582407,
#  66.86237456880937,
#  -81.07163867334486,
#  74.35136934881754,
#  -30.22678246151635,
#  17.91200865680888,
#  -63.7555254380697,
#  43.19139052674321,
#  -75.96230751690987,
#  2.535198877374872,
#  -1.4204494495290447,
#  -76.8765767360328,
#  30.94109098374394,
#  66.61377440102981,
#  -48.91857346656561,
#  -59.310174212221035,
#  -39.19995229219687,
#  -68.26868933184305,
#  59.69974285063181,
#  37.56610804159876,
#  89.4044662721248,
#  44.09542386925326,
#  20.271457804522196,
#  -47.97598450563058,
#  64.12453020492993,
#  66.13633180710112,
#  20.492507417364948,
#  -8.4085419276307,
#  65.07494314225816,
#  77.34026374197839,
#  85.70238120492347,
#  -45.461535757543736,
#  -12.016271427908462,
#  -43.71202974214321,
#  -89.24812785452278,
#  -34.78435796280045,
#  50.790156827817505,
#  23.731211047375794,
#  12.353252897508478,
#  41.596261048251165,
#  -37.49755044126633,
# ...

# %%
#Import linear regression from the SciPy status module
import scipy.stats as sc

# %%
#create an equal number of latitudes and temperatures
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

#perform linear regression
(slope, intercept, r_value, p_value, std_err) = sc.linregress(lats, temps)
#get the equation of the line
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
#calculate the regression line "y values" from the slope and intercept
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
#import matplotlib
import matplotlib.pyplot as plt
#create a scatter plot of the x and y values
plt.scatter(lats,temps)
#plot the regression line with the x-values and the y coordinates based on
plt.plot(lats, regress_values, "r")
#annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel("Latitude")
plt.ylabel("Temp")
plt.show()
